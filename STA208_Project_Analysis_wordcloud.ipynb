# %%
#set up
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
import pandas as pd
from wordcloud import WordCloud
import collections

# %%
data = pickle.load(open("All_email.txt","rb"))
#deal with year
data = data.loc[data.Year.isin(['1999','2000','2001','2002','2003','2004','2005','2006','2007'])]

# %%
collections.Counter(data.Year)
# Out:
# Counter({'1999': 7589,
#          '2000': 11363,
#          '2001': 10720,
#          '2002': 15943,
#          '2003': 2318,
#          '2004': 14047,
#          '2005': 19727,
#          '2006': 3956,
#          '2007': 74218})

# %% [markdown]
# ### Word Cloud

# %%
str(data.Content[1])
### To Kavi: 
## Note: Need some dadta processing : Get rid of \n \br and "Name: Content, dtype: object"~ 
# Note2: Do year (1999~2007) * Spam/Ham Word Cloud -> 9*2 = 18 combinations
# Out:
# "1     Your [m]ortgage application was approved. You...\n1    Our research indicates that in 1998 Wisvest pa...\n1    Hi, i've just updated from the gulus and I che...\n1    URL: http://boingboing.net/#85534142 Date: Not...\n1    There is NO stumbling on to it!   The greatest...\nName: Content, dtype: object"

# %%
#word cloud
# Generate a word cloud image
wordcloud = WordCloud().generate(str(data.Content[0:10]))

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(str(data['Content'][0]))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
